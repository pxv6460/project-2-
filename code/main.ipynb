# %%
# !pip install jupyterthemes

# %%
import pipeline as p_util
import pandas as pd

# %%
# preprocessed data given by the kaggle data set 
df= pd.read_csv("../Res/Star39552_balanced.csv")

# our groups preprocessed data made by Azlan 
df2 = pd.read_csv("../Res/preporcessed.csv")

# %%
df["TargetClass"].value_counts()
# Out:
# TargetClass
# 1    19776
# 0    19776
# Name: count, dtype: int64

# %%
df2["target"].value_counts()
# Out:
# target
# 0.0    22417
# 1.0    18916
# Name: count, dtype: int64

# %%
df
# Out:
#         Vmag    Plx  e_Plx    B-V SpType       Amag  TargetClass
# 0      10.00  31.66   6.19  1.213    K7V  22.502556            1
# 1       8.26   3.21   1.00  1.130  K0III  15.792525            0
# 2       8.27  12.75   1.06  0.596    F9V  18.797552            1
# 3       6.54   5.23   0.76  1.189  K1III  15.132508            0
# 4       8.52   0.96   0.72  0.173    B8V  13.431356            1
# ...      ...    ...    ...    ...    ...        ...          ...
# 39547   5.83   0.17   0.52  0.474  B7Iab   6.982245            0
# 39548   7.05  18.12   0.92  0.424    F5V  18.340790            1
# 39549   9.21   3.89   1.46  0.227   A1IV  17.159748            1
# 39550   9.01   2.13   1.46  1.467  M5III  15.651898            0
# 39551   9.12   3.82   0.79  0.480    F5V  17.030317            1
#
# [39552 rows x 7 columns]

# %%
df2
# Out:
#         Vmag      Plx  e_Plx    B-V        SpType  Distance (parsecs)  \
# 0       9.27  0.02190   3.10  0.999           K3V           45.662100
# 1       8.06  0.00775   0.97  0.370           F0V          129.032258
# 2       8.55  0.00287   1.11  0.902         G8III          348.432056
# 3      12.31  0.01880   4.99  1.336          M0V:           53.191489
# 4       9.05  0.00517   1.95  1.102  M6e-M8.5e Tc          193.423598
# ...      ...      ...    ...    ...           ...                 ...
# 41328   8.79  0.00089   1.28  1.194         K1III         1123.595506
# 41329   8.66  0.02804   2.25  1.008            M0           35.663338
# 41330   8.00  0.00041   0.92  0.854         F6Iab         2439.024390
# 41331   7.69  0.00660   0.92  1.110         K2III          151.515152
# 41332   6.98  0.00297   0.76 -0.143         B1.5V          336.700337
#
#        Distance (light years)      Amag  Temperature (K)  Luminosity (Sun=1)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39552 entries, 0 to 39551
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Vmag         39552 non-null  float64
#  1   Plx          39552 non-null  float64
#  2   e_Plx        39552 non-null  float64
#  3   B-V          39552 non-null  float64
#  4   SpType       39552 non-null  object
#  5   Amag         39552 non-null  float64
#  6   TargetClass  39552 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.1+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41333 entries, 0 to 41332
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Vmag                    41333 non-null  float64
#  1   Plx                     41333 non-null  float64
#  2   e_Plx                   41333 non-null  float64
#  3   B-V                     41333 non-null  float64
#  4   SpType                  41333 non-null  object
#  5   Distance (parsecs)      41333 non-null  float64
#  6   Distance (light years)  41333 non-null  float64
#  7   Amag                    41333 non-null  float64
#  8   Temperature (K)         41333 non-null  float64
#  9   Luminosity (Sun=1)      41333 non-null  float64
#  10  Radius (Sun=1)          41333 non-null  float64
#  11  target                  41333 non-null  float64
# dtypes: float64(11), object(1)
# memory usage: 3.8+ MB

# %%
# start of pipeline

# %%
data = []

# %%
dff, data = p_util.preprocess_data(df, "TargetClass", ["SpType"])
p_util.run_model(dff, data)
# Out:
# SVC
#               precision    recall  f1-score   support
#
#            1       0.85      0.91      0.88      4997
#            0       0.90      0.84      0.87      4891
#
#     accuracy                           0.88      9888
#    macro avg       0.88      0.88      0.88      9888
# weighted avg       0.88      0.88      0.88      9888
#
# ------------------------------------------------------------------------
# SVC undersampled
#               precision    recall  f1-score   support
#
#            1       0.85      0.91      0.88      4997
#            0       0.90      0.84      0.87      4891
#
#     accuracy                           0.88      9888
#    macro avg       0.88      0.88      0.88      9888
# weighted avg       0.88      0.88      0.88      9888
#
# ------------------------------------------------------------------------
# random forest
#               precision    recall  f1-score   support
#
#            1       0.85      0.91      0.88      4997
# ...

# %%
#dff2, data2 = p_util.preprocess_data(df2, "target", ["Temperature (K)" , "Distance (parsecs)", "SpType"])
#p_util.run_model(dff2, data2)

# %%
dff3, data3 = p_util.preprocess_data(df2, "target", ["B-V", "Distance (parsecs)", "SpType"])
p_util.run_model(dff3, data3)
# Out:
# SVC
#               precision    recall  f1-score   support
#
#            1       0.83      0.84      0.84      4728
#            0       0.86      0.86      0.86      5606
#
#     accuracy                           0.85     10334
#    macro avg       0.85      0.85      0.85     10334
# weighted avg       0.85      0.85      0.85     10334
#
# ------------------------------------------------------------------------
# SVC undersampled
#               precision    recall  f1-score   support
#
#            1       0.81      0.85      0.83      4728
#            0       0.87      0.83      0.85      5606
#
#     accuracy                           0.84     10334
#    macro avg       0.84      0.84      0.84     10334
# weighted avg       0.84      0.84      0.84     10334
#
# ------------------------------------------------------------------------
# random forest
#               precision    recall  f1-score   support
#
#            1       0.83      0.84      0.84      4728
# ...
